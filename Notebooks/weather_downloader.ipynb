# %%
from urllib.request import urlretrieve
import pandas as pd

# %% [markdown]
# This notebook allowed for the automated downloading of the data from the government of Canada's public database.

# %%
weather_stations=pd.read_csv('stations_shp.csv')

# %%
weather_stations.head()
# Out:
#    Unnamed: 0        Station Name          Province  Latitude  Longitude  \
# 0           0  100 MILE HOUSE 6NE  BRITISH COLUMBIA     51.68    -121.22
# 1           1           ABEE AGDM           ALBERTA     54.28    -112.97
# 2           2   ADDENBROKE ISLAND  BRITISH COLUMBIA     51.60    -127.86
# 3           3         AGASSIZ CDA  BRITISH COLUMBIA     49.24    -121.76
# 4           4         AGASSIZ RCS  BRITISH COLUMBIA     49.24    -121.76
#
#    Elevation Climate ID  WMO Identifier TC Identifier  First Year  Last Year  \
# 0      928.0    1165793             NaN           NaN        1987       2023
# 1      664.0    3010010         71285.0           XAF        1990       2024
# 2       21.3    1060080             NaN           WCZ        1978       2024
# 3       15.0    1100120             NaN           NaN        1889       2023
# 4       19.3    1100119         71113.0           WZA        1988       2024
#
#    HLY First Year  HLY Last Year  DLY First Year  DLY Last Year  \
# 0             NaN            NaN          1987.0         2023.0
# 1          1990.0         2024.0          2002.0         2024.0
# 2          1994.0         2001.0          1978.0         2024.0
# 3             NaN            NaN          1889.0         2023.0
# 4          1994.0         2024.0          1988.0         2024.0
#
#    MLY First Year  MLY Last Year               geometry
# 0          1987.0         2007.0  POINT (-121.22 51.68)
# 1          2002.0         2007.0  POINT (-112.97 54.28)
# 2          1978.0         2007.0   POINT (-127.86 51.6)
# 3          1889.0         2007.0  POINT (-121.76 49.24)
# 4          1988.0         2006.0  POINT (-121.76 49.24)

# %%
weather_stations.shape
# Out:
# (435, 18)

# %% [markdown]
# I'll be using the `weather_stations` table to loop through and download all the data needed from the following site:
# https://dd.weather.gc.ca/climate/observations/daily/csv/
#
#
# To do that cleanly, I will have to make a small adjustment to the way the provinces are currently displayed in the table. We will have to change the full name of the province to their respective 2 letter abbreviation.

# %%
weather_stations['Province'].value_counts()
# Out:
# Province
# QUEBEC                   146
# BRITISH COLUMBIA         123
# ONTARIO                   43
# ALBERTA                   30
# SASKATCHEWAN              28
# MANITOBA                  22
# NUNAVUT                   12
# NEWFOUNDLAND              11
# NOVA SCOTIA                6
# NEW BRUNSWICK              5
# YUKON TERRITORY            4
# NORTHWEST TERRITORIES      3
# PRINCE EDWARD ISLAND       2
# Name: count, dtype: int64

# %%
weather_stations= weather_stations.replace({'Province':{'BRITISH COLUMBIA':'BC','ONTARIO':'ON','QUEBEC':'QC','SASKATCHEWAN':'SK','ALBERTA':'AB','MANITOBA':'MB','NORTHWEST TERRITORIES':'NW','NEWFOUNDLAND':'NL','YUKON TERRITORY':'YK','NUNAVUT':'NU','NEW BRUNSWICK':'NB','NOVA SCOTIA':'NS','PRINCE EDWARD ISLAND':'PE'}})

# %%
weather_stations_list=list(weather_stations['Province'].unique())

# %%
weather_stations_list
# Out:
# ['BC', 'AB', 'NU', 'ON', 'QC', 'NL', 'NB', 'MB', 'SK', 'NS', 'NW', 'YK', 'PE']

# %%
weather_stations.head()
# Out:
#    Unnamed: 0        Station Name Province  Latitude  Longitude  Elevation  \
# 0           0  100 MILE HOUSE 6NE       BC     51.68    -121.22      928.0
# 1           1           ABEE AGDM       AB     54.28    -112.97      664.0
# 2           2   ADDENBROKE ISLAND       BC     51.60    -127.86       21.3
# 3           3         AGASSIZ CDA       BC     49.24    -121.76       15.0
# 4           4         AGASSIZ RCS       BC     49.24    -121.76       19.3
#
#   Climate ID  WMO Identifier TC Identifier  First Year  Last Year  \
# 0    1165793             NaN           NaN        1987       2023
# 1    3010010         71285.0           XAF        1990       2024
# 2    1060080             NaN           WCZ        1978       2024
# 3    1100120             NaN           NaN        1889       2023
# 4    1100119         71113.0           WZA        1988       2024
#
#    HLY First Year  HLY Last Year  DLY First Year  DLY Last Year  \
# 0             NaN            NaN          1987.0         2023.0
# 1          1990.0         2024.0          2002.0         2024.0
# 2          1994.0         2001.0          1978.0         2024.0
# 3             NaN            NaN          1889.0         2023.0
# 4          1994.0         2024.0          1988.0         2024.0
#
#    MLY First Year  MLY Last Year               geometry
# 0          1987.0         2007.0  POINT (-121.22 51.68)
# 1          2002.0         2007.0  POINT (-112.97 54.28)
# 2          1978.0         2007.0   POINT (-127.86 51.6)
# 3          1889.0         2007.0  POINT (-121.76 49.24)
# 4          1988.0         2006.0  POINT (-121.76 49.24)

# %% [markdown]
# Next I'm creating a date range to add into my `for` loop to ensure the loop downloads only the files that have those dates.

# %%
date_range = pd.date_range('1990','2023',freq='ME').strftime('%Y-%m')

date_range
# Out:
# Index(['1990-01', '1990-02', '1990-03', '1990-04', '1990-05', '1990-06',
#        '1990-07', '1990-08', '1990-09', '1990-10',
#        ...
#        '2022-03', '2022-04', '2022-05', '2022-06', '2022-07', '2022-08',
#        '2022-09', '2022-10', '2022-11', '2022-12'],
#       dtype='object', length=396)

# %%
#creating an empty dataframe to start
weather_data_df=pd.DataFrame()

# %%
# downloading weather data
for prov in weather_stations_list: #going through each province
    
    station= list(weather_stations['Climate ID'][weather_stations['Province']==prov].unique()) #going through each station from the province
    for id in station:
       
        for date in date_range: #selecting the date range for each province
            
            try:
                download=urlretrieve(url=f'https://dd.weather.gc.ca/climate/observations/daily/csv/{prov}/climate_daily_{prov}_{id}_{date}_P1D.csv',
                                     filename=f'Data/Weather_Daily/climate_daily_{prov}_{id}_{date}_P1D.csv')
                print(f'Downloading from {prov}')
            except:
                print('pass')
                continue
# Out:
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# pass
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC
# Downloading from BC

# %% [markdown]
# Everything has been downloaded. Let's move on to the daily weather preprossessing
